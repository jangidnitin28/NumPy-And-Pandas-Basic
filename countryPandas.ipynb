# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Countries.csv")

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df
# Out:
#                             country  \
# 0                       Afghanistan
# 1                           Albania
# 2                           Algeria
# 3                           Andorra
# 4                            Angola
# 5               Antigua and Barbuda
# 6                         Argentina
# 7                           Armenia
# 8                         Australia
# 9                           Austria
# 10                       Azerbaijan
# 11                          Bahrain
# 12                       Bangladesh
# 13                         Barbados
# 14                          Belarus
# 15                          Belgium
# 16                           Belize
# 17                            Benin
# 18                           Bhutan
# 19                          Bolivia
# 20           Bosnia and Herzegovina
# 21                         Botswana
# 22                           Brazil
# 23                           Brunei
# 24                         Bulgaria
# ...

# %%
df[['population','country']].max()
# Out:
# population    1417173173
# country         Zimbabwe
# dtype: object

# %%
df[['country','population']].min()
# Out:
# country       Afghanistan
# population          11312
# dtype: object

# %%
df[['population','capital_city']].max()
# Out:
# population      1417173173
# capital_city        Zagreb
# dtype: object

# %%
df[['democracy_score','country']].sort_values(by='democracy_score' , ascending=False).head()
# Out:
#      democracy_score      country
# 127             9.87       Norway
# 74              9.58      Iceland
# 164             9.39       Sweden
# 122             9.26  New Zealand
# 46              9.22      Denmark

# %%
df['region'].nunique()
# Out:
# 22

# %%
df[df['region'] == 'Southern Europe']['country'].count()
# Out:
# np.int64(15)

# %%
df_sorted = df[['population','country','political_leader']].sort_values(by='population',ascending=False)

# %%
df_sorted.iloc[2][['country','political_leader','population']]
# Out:
# country             United States
# political_leader        Joe Biden
# population              333287557
# Name: 184, dtype: object

# %%
df[df['political_leader'].isnull()]['country']
# Out:
# 27                         Cabo Verde
# 151                   Slovak Republic
# 159               St. Kitts and Nevis
# 160                         St. Lucia
# 161    St. Vincent and the Grenadines
# 172                       Timor-Leste
# 190                West Bank and Gaza
# Name: country, dtype: object

# %%
df[df['country_long'].str.contains('Republic', na=False)].shape[0]
# Out:
# 125

# %%
df[df['region'].str.contains('Africa')]#.sort_values(by='population', ascending=False).iloc[0][['country','population']]
# Out:
#                       country                                  country_long  \
# 2                     Algeria       People's Democratic Republic of Algeria
# 4                      Angola                   People's Republic of Angola
# 17                      Benin                             Republic of Benin
# 21                   Botswana                          Republic of Botswana
# 25               Burkina Faso                                  Burkina Faso
# 26                    Burundi                           Republic of Burundi
# 27                 Cabo Verde                        Republic of Cabo Verde
# 29                   Cameroon                          Republic of Cameroon
# 31   Central African Republic                      Central African Republic
# 32                       Chad                              Republic of Chad
# 36                    Comoros                          Union of the Comoros
# ...
